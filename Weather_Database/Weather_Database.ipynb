# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from config import weather_api_key
from datetime import datetime

# %%
lats = np.random.uniform(-90, 90, size = 2000)
longs = np.random.uniform(-180, 180, size = 2000)
lat_longs = zip(lats, longs)
lat_longs

# %%
coordinates = list(lat_longs)

# %%
from citipy import citipy

# %%
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0],coordinate[1]).city_name
    
    if city not in cities:
        cities.append(city)
        
len(cities)
# Out:
# 750

# %%
import requests
requests.__version__
# Out:
# '2.25.1'

# %%
url = "http://api.openweathermap.org/data/2.5/weather?APPID=" + weather_api_key

# %%
city_data = []

print("Beginning Data Retrieval        ")
print("--------------------------------")

#create counters
recordCounter = 1
setCounter = 1

#Loop through all the cities in our list

for i, city in enumerate(cities):

    #Group citis in sets of 50 for logging purposes
    if(i % 50 == 0 and i >= 50):
        setCounter += 1
        recordCounter += 1
        
    #Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ", "+") + "&units=imperial"
    city_weather = requests.get(city_url).json()
    #Log the URL, record, and set number and the city.
    print(f"Processing Record {recordCounter} of Set {setCounter} | {city}")
    
    # Add 1 to the record count.
    recordCounter += 1
    
    try:
        lat = city_weather["coord"]["lat"]
        lng = city_weather["coord"]["lon"]
        maxTemp = city_weather["main"]["temp_max"]
        humidity = city_weather["main"]["humidity"]
        clouds = city_weather["clouds"]["all"]
        wind = city_weather["wind"]["speed"]
        country = city_weather["sys"]["country"]
        description = city_weather["weather"][0]["description"]
        
        #Conver the date to ISO standard
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        city_data.append({"City" : city.title(),
                         "Lat" : lat,
                         "Lng" : lng,
                         "Max Temp" : maxTemp,
                         "Humidity" : humidity,
                         "Cloudiness" : clouds,
                         "Wind Speed" : wind,
                         "Country" : country,
                         "Date" : city_date,
                         "Current Description": description})
        
    except:
        print("City not found. Skipping....")
        pass
print("--------------------------")
print("Data Retrieval Complete   ")
print("--------------------------")
# Out:
# Beginning Data Retrieval
# --------------------------------
# Processing Record 1 of Set 1 | bilibino
# Processing Record 2 of Set 1 | port macquarie
# Processing Record 3 of Set 1 | ferme-neuve
# Processing Record 4 of Set 1 | hermanus
# Processing Record 5 of Set 1 | ushuaia
# Processing Record 6 of Set 1 | paita
# Processing Record 7 of Set 1 | punta arenas
# Processing Record 8 of Set 1 | mahebourg
# Processing Record 9 of Set 1 | yellowknife
# Processing Record 10 of Set 1 | tombouctou
# Processing Record 11 of Set 1 | albany
# Processing Record 12 of Set 1 | okhotsk
# Processing Record 13 of Set 1 | ulaanbaatar
# Processing Record 14 of Set 1 | hanna
# Processing Record 15 of Set 1 | namibe
# Processing Record 16 of Set 1 | suslovo
# Processing Record 17 of Set 1 | khatanga
# Processing Record 18 of Set 1 | bluff
# Processing Record 19 of Set 1 | lolua
# City not found. Skipping....
# Processing Record 20 of Set 1 | taolanaro
# City not found. Skipping....
# Processing Record 21 of Set 1 | constitucion
# Processing Record 22 of Set 1 | kapaa
# Processing Record 23 of Set 1 | itarema
# Processing Record 24 of Set 1 | roald
# Processing Record 25 of Set 1 | kaitangata
# Processing Record 26 of Set 1 | barentsburg
# City not found. Skipping....
# Processing Record 27 of Set 1 | codrington
# Processing Record 28 of Set 1 | ceres
# Processing Record 29 of Set 1 | chicama
# Processing Record 30 of Set 1 | vaini
# Processing Record 31 of Set 1 | vila franca do campo
# Processing Record 32 of Set 1 | mount isa
# Processing Record 33 of Set 1 | nikolskoye
# Processing Record 34 of Set 1 | port alfred
# Processing Record 35 of Set 1 | qaanaaq
# Processing Record 36 of Set 1 | salalah
# Processing Record 37 of Set 1 | tsihombe
# City not found. Skipping....
# Processing Record 38 of Set 1 | dingle
# Processing Record 39 of Set 1 | rikitea
# Processing Record 40 of Set 1 | coquimbo
# Processing Record 41 of Set 1 | mataura
# Processing Record 42 of Set 1 | bredasdorp
# Processing Record 43 of Set 1 | mareeba
# Processing Record 44 of Set 1 | arraial do cabo
# Processing Record 45 of Set 1 | narsaq
# Processing Record 46 of Set 1 | kormilovka
# Processing Record 47 of Set 1 | vaitape
# Processing Record 48 of Set 1 | dikson
# Processing Record 49 of Set 1 | kapit
# Processing Record 50 of Set 1 | noumea
# Processing Record 52 of Set 2 | ballina
# Processing Record 53 of Set 2 | barrow
# Processing Record 54 of Set 2 | hobart
# Processing Record 55 of Set 2 | butaritari
# Processing Record 56 of Set 2 | severo-kurilsk
# Processing Record 57 of Set 2 | shimanovsk
# Processing Record 58 of Set 2 | port elizabeth
# Processing Record 59 of Set 2 | carman
# Processing Record 60 of Set 2 | rumoi
# Processing Record 61 of Set 2 | hilo
# Processing Record 62 of Set 2 | moerai
# Processing Record 63 of Set 2 | bambous virieux
# Processing Record 64 of Set 2 | qasigiannguit
# Processing Record 65 of Set 2 | saleaula
# City not found. Skipping....
# Processing Record 66 of Set 2 | phan rang
# City not found. Skipping....
# Processing Record 67 of Set 2 | pangai
# Processing Record 68 of Set 2 | lebu
# Processing Record 69 of Set 2 | ribeira grande
# Processing Record 70 of Set 2 | nanortalik
# Processing Record 71 of Set 2 | antofagasta
# Processing Record 72 of Set 2 | san quintin
# Processing Record 73 of Set 2 | aflu
# City not found. Skipping....
# Processing Record 74 of Set 2 | pringsewu
# Processing Record 75 of Set 2 | sentyabrskiy
# City not found. Skipping....
# Processing Record 76 of Set 2 | grand gaube
# Processing Record 77 of Set 2 | busselton
# Processing Record 78 of Set 2 | bonfim
# Processing Record 79 of Set 2 | brae
# Processing Record 80 of Set 2 | saint-philippe
# Processing Record 81 of Set 2 | chagda
# City not found. Skipping....
# Processing Record 82 of Set 2 | souillac
# Processing Record 83 of Set 2 | torbay
# Processing Record 84 of Set 2 | georgetown
# Processing Record 85 of Set 2 | altamira
# Processing Record 86 of Set 2 | banda aceh
# Processing Record 87 of Set 2 | cape town
# Processing Record 88 of Set 2 | kodiak
# Processing Record 89 of Set 2 | vence
# Processing Record 90 of Set 2 | eisenerz
# Processing Record 91 of Set 2 | kalmunai
# Processing Record 92 of Set 2 | mantua
# Processing Record 93 of Set 2 | puerto ayora
# Processing Record 94 of Set 2 | tomatlan
# Processing Record 95 of Set 2 | kasongo
# Processing Record 96 of Set 2 | tual
# Processing Record 97 of Set 2 | necochea
# Processing Record 98 of Set 2 | pisco
# Processing Record 99 of Set 2 | taitung
# Processing Record 100 of Set 2 | atuona
# Processing Record 101 of Set 2 | ambilobe
# Processing Record 103 of Set 3 | lavrentiya
# Processing Record 104 of Set 3 | carutapera
# Processing Record 105 of Set 3 | scottsbluff
# Processing Record 106 of Set 3 | bethel
# Processing Record 107 of Set 3 | yarmouth
# Processing Record 108 of Set 3 | illoqqortoormiut
# City not found. Skipping....
# Processing Record 109 of Set 3 | chuy
# Processing Record 110 of Set 3 | geraldton
# Processing Record 111 of Set 3 | broken hill
# Processing Record 112 of Set 3 | tucupita
# Processing Record 113 of Set 3 | taman
# Processing Record 114 of Set 3 | mar del plata
# Processing Record 115 of Set 3 | palmer
# Processing Record 116 of Set 3 | chokurdakh
# Processing Record 117 of Set 3 | visby
# Processing Record 118 of Set 3 | saurimo
# Processing Record 119 of Set 3 | hofn
# Processing Record 120 of Set 3 | krasnyy yar
# Processing Record 121 of Set 3 | meulaboh
# Processing Record 122 of Set 3 | luanda
# Processing Record 123 of Set 3 | alugan
# Processing Record 124 of Set 3 | castro
# Processing Record 125 of Set 3 | sioux lookout
# Processing Record 126 of Set 3 | bilma
# Processing Record 127 of Set 3 | chilca
# Processing Record 128 of Set 3 | haines junction
# Processing Record 129 of Set 3 | kingisepp
# Processing Record 130 of Set 3 | banepa
# Processing Record 131 of Set 3 | abu kamal
# Processing Record 132 of Set 3 | upernavik
# Processing Record 133 of Set 3 | deputatskiy
# Processing Record 134 of Set 3 | mount gambier
# Processing Record 135 of Set 3 | alghero
# Processing Record 136 of Set 3 | saldanha
# Processing Record 137 of Set 3 | namatanai
# Processing Record 138 of Set 3 | talnakh
# Processing Record 139 of Set 3 | puerto padre
# Processing Record 140 of Set 3 | minsk
# Processing Record 141 of Set 3 | kruisfontein
# Processing Record 142 of Set 3 | jamestown
# Processing Record 143 of Set 3 | meyungs
# City not found. Skipping....
# Processing Record 144 of Set 3 | zonguldak
# Processing Record 145 of Set 3 | norman wells
# Processing Record 146 of Set 3 | caribou
# Processing Record 147 of Set 3 | riyadh
# Processing Record 148 of Set 3 | warqla
# City not found. Skipping....
# Processing Record 149 of Set 3 | bubaque
# Processing Record 150 of Set 3 | abu samrah
# Processing Record 151 of Set 3 | abnub
# Processing Record 152 of Set 3 | dzilam gonzalez
# Processing Record 154 of Set 4 | bathsheba
# Processing Record 155 of Set 4 | tilichiki
# Processing Record 156 of Set 4 | sorland
# Processing Record 157 of Set 4 | east london
# Processing Record 158 of Set 4 | jalu
# Processing Record 159 of Set 4 | muroto
# Processing Record 160 of Set 4 | peshkovo
# Processing Record 161 of Set 4 | marystown
# Processing Record 162 of Set 4 | muisne
# Processing Record 163 of Set 4 | belushya guba
# City not found. Skipping....
# Processing Record 164 of Set 4 | inhambane
# Processing Record 165 of Set 4 | kavieng
# Processing Record 166 of Set 4 | buta
# Processing Record 167 of Set 4 | bulgan
# Processing Record 168 of Set 4 | vaasa
# Processing Record 169 of Set 4 | tabou
# Processing Record 170 of Set 4 | kasempa
# Processing Record 171 of Set 4 | alihe
# Processing Record 172 of Set 4 | nabire
# Processing Record 173 of Set 4 | pevek
# Processing Record 174 of Set 4 | cidreira
# Processing Record 175 of Set 4 | hasaki
# Processing Record 176 of Set 4 | katsuura
# Processing Record 177 of Set 4 | the valley
# Processing Record 178 of Set 4 | pareora
# Processing Record 179 of Set 4 | catamarca
# Processing Record 180 of Set 4 | nautla
# Processing Record 181 of Set 4 | touros
# Processing Record 182 of Set 4 | yulara
# Processing Record 183 of Set 4 | davila
# Processing Record 184 of Set 4 | nadym
# Processing Record 185 of Set 4 | ola
# Processing Record 186 of Set 4 | vorukh
# Processing Record 187 of Set 4 | sitka
# Processing Record 188 of Set 4 | manitouwadge
# Processing Record 189 of Set 4 | faya
# Processing Record 190 of Set 4 | avarua
# Processing Record 191 of Set 4 | amot
# Processing Record 192 of Set 4 | aklavik
# Processing Record 193 of Set 4 | victoria
# Processing Record 194 of Set 4 | waipawa
# Processing Record 195 of Set 4 | rio gallegos
# Processing Record 196 of Set 4 | sao jose da coroa grande
# Processing Record 197 of Set 4 | tasiilaq
# Processing Record 198 of Set 4 | hwange
# Processing Record 199 of Set 4 | naze
# Processing Record 200 of Set 4 | ukiah
# Processing Record 201 of Set 4 | labuhan
# Processing Record 202 of Set 4 | rabo de peixe
# Processing Record 203 of Set 4 | samusu
# City not found. Skipping....
# Processing Record 205 of Set 5 | constantine
# Processing Record 206 of Set 5 | saint andrews
# Processing Record 207 of Set 5 | qui nhon
# Processing Record 208 of Set 5 | saskylakh
# Processing Record 209 of Set 5 | ilulissat
# Processing Record 210 of Set 5 | moncton
# Processing Record 211 of Set 5 | les cayes
# Processing Record 212 of Set 5 | zeya
# Processing Record 213 of Set 5 | lagoa
# Processing Record 214 of Set 5 | alofi
# Processing Record 215 of Set 5 | sao gabriel da cachoeira
# Processing Record 216 of Set 5 | muslyumovo
# Processing Record 217 of Set 5 | banamba
# Processing Record 218 of Set 5 | bengkulu
# Processing Record 219 of Set 5 | sangar
# Processing Record 220 of Set 5 | erding
# Processing Record 221 of Set 5 | grand river south east
# City not found. Skipping....
# Processing Record 222 of Set 5 | amderma
# City not found. Skipping....
# Processing Record 223 of Set 5 | henties bay
# Processing Record 224 of Set 5 | sumenep
# Processing Record 225 of Set 5 | puerto escondido
# Processing Record 226 of Set 5 | zhigansk
# Processing Record 227 of Set 5 | mys shmidta
# City not found. Skipping....
# Processing Record 228 of Set 5 | dharchula
# Processing Record 229 of Set 5 | hithadhoo
# Processing Record 230 of Set 5 | cayenne
# Processing Record 231 of Set 5 | husavik
# Processing Record 232 of Set 5 | kumano
# Processing Record 233 of Set 5 | tuatapere
# Processing Record 234 of Set 5 | brownsville
# Processing Record 235 of Set 5 | taoudenni
# Processing Record 236 of Set 5 | aykhal
# Processing Record 237 of Set 5 | clyde river
# Processing Record 238 of Set 5 | nizhneyansk
# City not found. Skipping....
# Processing Record 239 of Set 5 | ahmadpur east
# Processing Record 240 of Set 5 | hobyo
# Processing Record 241 of Set 5 | jhang
# Processing Record 242 of Set 5 | los llanos de aridane
# Processing Record 243 of Set 5 | longyearbyen
# Processing Record 244 of Set 5 | hanmer springs
# Processing Record 245 of Set 5 | tuktoyaktuk
# Processing Record 246 of Set 5 | minab
# Processing Record 247 of Set 5 | hilton head island
# Processing Record 248 of Set 5 | solok
# Processing Record 249 of Set 5 | grindavik
# Processing Record 250 of Set 5 | chegdomyn
# Processing Record 251 of Set 5 | nanning
# Processing Record 252 of Set 5 | mackenzie
# Processing Record 253 of Set 5 | uarini
# Processing Record 254 of Set 5 | esperance
# Processing Record 256 of Set 6 | pouebo
# Processing Record 257 of Set 6 | tura
# Processing Record 258 of Set 6 | mwense
# Processing Record 259 of Set 6 | koshurnikovo
# Processing Record 260 of Set 6 | port moresby
# Processing Record 261 of Set 6 | yinchuan
# Processing Record 262 of Set 6 | vardo
# Processing Record 263 of Set 6 | san policarpo
# Processing Record 264 of Set 6 | oistins
# Processing Record 265 of Set 6 | jabinyanah
# Processing Record 266 of Set 6 | portland
# Processing Record 267 of Set 6 | port hardy
# Processing Record 268 of Set 6 | thompson
# Processing Record 269 of Set 6 | innisfail
# Processing Record 270 of Set 6 | buala
# Processing Record 271 of Set 6 | mildura
# Processing Record 272 of Set 6 | marsh harbour
# Processing Record 273 of Set 6 | kibala
# Processing Record 274 of Set 6 | batemans bay
# Processing Record 275 of Set 6 | attawapiskat
# City not found. Skipping....
# Processing Record 276 of Set 6 | buchanan
# Processing Record 277 of Set 6 | tunxi
# City not found. Skipping....
# Processing Record 278 of Set 6 | new norfolk
# Processing Record 279 of Set 6 | cherskiy
# Processing Record 280 of Set 6 | ahipara
# Processing Record 281 of Set 6 | vestmannaeyjar
# Processing Record 282 of Set 6 | beira
# Processing Record 283 of Set 6 | santa cruz de tenerife
# Processing Record 284 of Set 6 | lakes entrance
# Processing Record 285 of Set 6 | alyangula
# Processing Record 286 of Set 6 | sungaipenuh
# Processing Record 287 of Set 6 | carnarvon
# Processing Record 288 of Set 6 | trelew
# Processing Record 289 of Set 6 | chernyshevskiy
# Processing Record 290 of Set 6 | marica
# Processing Record 291 of Set 6 | chapais
# Processing Record 292 of Set 6 | kinkala
# Processing Record 293 of Set 6 | iqaluit
# Processing Record 294 of Set 6 | quilmana
# Processing Record 295 of Set 6 | tabuk
# Processing Record 296 of Set 6 | hovd
# Processing Record 297 of Set 6 | ponta do sol
# Processing Record 298 of Set 6 | rundu
# Processing Record 299 of Set 6 | ostrovnoy
# Processing Record 300 of Set 6 | nouadhibou
# Processing Record 301 of Set 6 | kottapalli
# Processing Record 302 of Set 6 | paradwip
# City not found. Skipping....
# Processing Record 303 of Set 6 | faanui
# Processing Record 304 of Set 6 | solnechnyy
# Processing Record 305 of Set 6 | saint-francois
# Processing Record 307 of Set 7 | leh
# Processing Record 308 of Set 7 | tambul
# City not found. Skipping....
# Processing Record 309 of Set 7 | bagdarin
# Processing Record 310 of Set 7 | sabzevar
# Processing Record 311 of Set 7 | kavaratti
# Processing Record 312 of Set 7 | edd
# Processing Record 313 of Set 7 | port-gentil
# Processing Record 314 of Set 7 | moose factory
# Processing Record 315 of Set 7 | diffa
# Processing Record 316 of Set 7 | mehamn
# Processing Record 317 of Set 7 | srednekolymsk
# Processing Record 318 of Set 7 | isangel
# Processing Record 319 of Set 7 | pemangkat
# Processing Record 320 of Set 7 | korla
# Processing Record 321 of Set 7 | provideniya
# Processing Record 322 of Set 7 | sambava
# Processing Record 323 of Set 7 | galveston
# Processing Record 324 of Set 7 | camacari
# Processing Record 325 of Set 7 | pshekhskaya
# Processing Record 326 of Set 7 | ndele
# Processing Record 327 of Set 7 | cabo san lucas
# Processing Record 328 of Set 7 | nguiu
# City not found. Skipping....
# Processing Record 329 of Set 7 | komsomolskiy
# Processing Record 330 of Set 7 | bolshaya glushitsa
# Processing Record 331 of Set 7 | airai
# Processing Record 332 of Set 7 | loiza
# Processing Record 333 of Set 7 | carbonia
# Processing Record 334 of Set 7 | huilong
# Processing Record 335 of Set 7 | ambanja
# Processing Record 336 of Set 7 | yerbogachen
# Processing Record 337 of Set 7 | karaul
# City not found. Skipping....
# Processing Record 338 of Set 7 | nouakchott
# Processing Record 339 of Set 7 | adelaide
# Processing Record 340 of Set 7 | mogadishu
# Processing Record 341 of Set 7 | trinidad
# Processing Record 342 of Set 7 | cazaje
# City not found. Skipping....
# Processing Record 343 of Set 7 | oban
# Processing Record 344 of Set 7 | gelemso
# Processing Record 345 of Set 7 | kishi
# Processing Record 346 of Set 7 | herat
# Processing Record 347 of Set 7 | palabuhanratu
# City not found. Skipping....
# Processing Record 348 of Set 7 | quatre cocos
# Processing Record 349 of Set 7 | dunedin
# Processing Record 350 of Set 7 | rosetta
# Processing Record 351 of Set 7 | lorengau
# Processing Record 352 of Set 7 | kovur
# Processing Record 353 of Set 7 | kapuskasing
# Processing Record 354 of Set 7 | riobamba
# Processing Record 355 of Set 7 | muyezerskiy
# Processing Record 356 of Set 7 | tiarei
# Processing Record 358 of Set 8 | mocuba
# Processing Record 359 of Set 8 | kibre mengist
# Processing Record 360 of Set 8 | lodingen
# Processing Record 361 of Set 8 | port lincoln
# Processing Record 362 of Set 8 | hami
# Processing Record 363 of Set 8 | fairbanks
# Processing Record 364 of Set 8 | mendi
# Processing Record 365 of Set 8 | gizo
# Processing Record 366 of Set 8 | roebourne
# Processing Record 367 of Set 8 | axim
# Processing Record 368 of Set 8 | camacha
# Processing Record 369 of Set 8 | kirkuk
# Processing Record 370 of Set 8 | dhana
# Processing Record 371 of Set 8 | poum
# Processing Record 372 of Set 8 | liliani
# Processing Record 373 of Set 8 | tumannyy
# City not found. Skipping....
# Processing Record 374 of Set 8 | halifax
# Processing Record 375 of Set 8 | lyngseidet
# Processing Record 376 of Set 8 | matara
# Processing Record 377 of Set 8 | ambunti
# Processing Record 378 of Set 8 | kharitonovo
# Processing Record 379 of Set 8 | paamiut
# Processing Record 380 of Set 8 | lazaro cardenas
# Processing Record 381 of Set 8 | filingue
# Processing Record 382 of Set 8 | alice
# Processing Record 383 of Set 8 | dongying
# Processing Record 384 of Set 8 | port blair
# Processing Record 385 of Set 8 | dongning
# Processing Record 386 of Set 8 | san cristobal
# Processing Record 387 of Set 8 | kamenskoye
# City not found. Skipping....
# Processing Record 388 of Set 8 | halalo
# City not found. Skipping....
# Processing Record 389 of Set 8 | labutta
# City not found. Skipping....
# Processing Record 390 of Set 8 | zitsa
# Processing Record 391 of Set 8 | tambulan
# City not found. Skipping....
# Processing Record 392 of Set 8 | alvorada
# Processing Record 393 of Set 8 | mentok
# City not found. Skipping....
# Processing Record 394 of Set 8 | shenkursk
# Processing Record 395 of Set 8 | scottsburgh
# City not found. Skipping....
# Processing Record 396 of Set 8 | wanning
# Processing Record 397 of Set 8 | caravelas
# Processing Record 398 of Set 8 | bad rappenau
# Processing Record 399 of Set 8 | quchan
# Processing Record 400 of Set 8 | road town
# Processing Record 401 of Set 8 | vicosa
# Processing Record 402 of Set 8 | pacific grove
# Processing Record 403 of Set 8 | hambantota
# Processing Record 404 of Set 8 | coos bay
# Processing Record 405 of Set 8 | vao
# Processing Record 406 of Set 8 | mahon
# Processing Record 407 of Set 8 | aripuana
# Processing Record 409 of Set 9 | bahia honda
# Processing Record 410 of Set 9 | qostanay
# Processing Record 411 of Set 9 | kerema
# Processing Record 412 of Set 9 | phayao
# Processing Record 413 of Set 9 | hoquiam
# Processing Record 414 of Set 9 | sedelnikovo
# City not found. Skipping....
# Processing Record 415 of Set 9 | saint-georges
# Processing Record 416 of Set 9 | lompoc
# Processing Record 417 of Set 9 | mrirt
# City not found. Skipping....
# Processing Record 418 of Set 9 | havre-saint-pierre
# Processing Record 419 of Set 9 | timizart
# Processing Record 420 of Set 9 | kurilsk
# Processing Record 421 of Set 9 | kautokeino
# Processing Record 422 of Set 9 | traian
# Processing Record 423 of Set 9 | ondjiva
# Processing Record 424 of Set 9 | sovetskiy
# Processing Record 425 of Set 9 | playas
# Processing Record 426 of Set 9 | lasa
# Processing Record 427 of Set 9 | beloha
# Processing Record 428 of Set 9 | altay
# Processing Record 429 of Set 9 | prainha
# Processing Record 430 of Set 9 | tanete
# Processing Record 431 of Set 9 | coracora
# Processing Record 432 of Set 9 | umm lajj
# Processing Record 433 of Set 9 | broome
# Processing Record 434 of Set 9 | guerrero negro
# Processing Record 435 of Set 9 | verkhnevilyuysk
# Processing Record 436 of Set 9 | porto santo
# Processing Record 437 of Set 9 | sabang
# Processing Record 438 of Set 9 | santa eulalia del rio
# City not found. Skipping....
# Processing Record 439 of Set 9 | aguacatan
# Processing Record 440 of Set 9 | reykjavik
# Processing Record 441 of Set 9 | pishin
# Processing Record 442 of Set 9 | vanavara
# Processing Record 443 of Set 9 | orichi
# Processing Record 444 of Set 9 | pangnirtung
# Processing Record 445 of Set 9 | najran
# Processing Record 446 of Set 9 | acapulco
# Processing Record 447 of Set 9 | rawannawi
# City not found. Skipping....
# Processing Record 448 of Set 9 | eyl
# Processing Record 449 of Set 9 | vaitupu
# City not found. Skipping....
# Processing Record 450 of Set 9 | oksbol
# Processing Record 451 of Set 9 | manyana
# Processing Record 452 of Set 9 | dod ballapur
# Processing Record 453 of Set 9 | adrar
# Processing Record 454 of Set 9 | isiolo
# Processing Record 455 of Set 9 | great falls
# Processing Record 456 of Set 9 | baykit
# Processing Record 457 of Set 9 | manakara
# Processing Record 458 of Set 9 | west wendover
# Processing Record 460 of Set 10 | japura
# Processing Record 461 of Set 10 | salinas
# Processing Record 462 of Set 10 | ravar
# Processing Record 463 of Set 10 | gulshat
# City not found. Skipping....
# Processing Record 464 of Set 10 | udachnyy
# Processing Record 465 of Set 10 | puerto madero
# Processing Record 466 of Set 10 | kurtalan
# Processing Record 467 of Set 10 | bambanglipuro
# Processing Record 468 of Set 10 | maniitsoq
# Processing Record 469 of Set 10 | besikduzu
# Processing Record 470 of Set 10 | ucluelet
# Processing Record 471 of Set 10 | iracoubo
# Processing Record 472 of Set 10 | san jose
# Processing Record 473 of Set 10 | buraydah
# Processing Record 474 of Set 10 | wulanhaote
# City not found. Skipping....
# Processing Record 475 of Set 10 | pingliang
# Processing Record 476 of Set 10 | asau
# Processing Record 477 of Set 10 | panyutyne
# Processing Record 478 of Set 10 | serra
# Processing Record 479 of Set 10 | mutare
# Processing Record 480 of Set 10 | orange
# Processing Record 481 of Set 10 | ngukurr
# City not found. Skipping....
# Processing Record 482 of Set 10 | burewala
# Processing Record 483 of Set 10 | tres picos
# Processing Record 484 of Set 10 | griffith
# Processing Record 485 of Set 10 | along
# Processing Record 486 of Set 10 | montepuez
# Processing Record 487 of Set 10 | ihosy
# Processing Record 488 of Set 10 | muros
# Processing Record 489 of Set 10 | paramonga
# Processing Record 490 of Set 10 | sibolga
# Processing Record 491 of Set 10 | zhezkazgan
# Processing Record 492 of Set 10 | tiksi
# Processing Record 493 of Set 10 | hervey bay
# Processing Record 494 of Set 10 | kununurra
# Processing Record 495 of Set 10 | okha
# Processing Record 496 of Set 10 | bainbridge
# Processing Record 497 of Set 10 | kemijarvi
# Processing Record 498 of Set 10 | padang
# Processing Record 499 of Set 10 | muzquiz
# City not found. Skipping....
# Processing Record 500 of Set 10 | ancud
# Processing Record 501 of Set 10 | verkhoyansk
# Processing Record 502 of Set 10 | tecoanapa
# Processing Record 503 of Set 10 | america dourada
# Processing Record 504 of Set 10 | saint george
# Processing Record 505 of Set 10 | elk city
# Processing Record 506 of Set 10 | lisakovsk
# Processing Record 507 of Set 10 | pinega
# Processing Record 508 of Set 10 | sao filipe
# Processing Record 509 of Set 10 | zhengjiatun
# Processing Record 511 of Set 11 | calvinia
# Processing Record 512 of Set 11 | yar-sale
# Processing Record 513 of Set 11 | ayr
# Processing Record 514 of Set 11 | port hedland
# Processing Record 515 of Set 11 | la ronge
# Processing Record 516 of Set 11 | pakxan
# Processing Record 517 of Set 11 | bodden town
# Processing Record 518 of Set 11 | gazojak
# Processing Record 519 of Set 11 | orlik
# Processing Record 520 of Set 11 | barth
# Processing Record 521 of Set 11 | olavarria
# Processing Record 522 of Set 11 | mwinilunga
# Processing Record 523 of Set 11 | gavle
# Processing Record 524 of Set 11 | ongandjera
# Processing Record 525 of Set 11 | hudiksvall
# Processing Record 526 of Set 11 | leningradskiy
# Processing Record 527 of Set 11 | cabedelo
# Processing Record 528 of Set 11 | san patricio
# Processing Record 529 of Set 11 | kenai
# Processing Record 530 of Set 11 | praia da vitoria
# Processing Record 531 of Set 11 | bandundu
# Processing Record 532 of Set 11 | kloulklubed
# Processing Record 533 of Set 11 | hamilton
# Processing Record 534 of Set 11 | paro
# Processing Record 535 of Set 11 | ritchie
# Processing Record 536 of Set 11 | banmo
# City not found. Skipping....
# Processing Record 537 of Set 11 | oro valley
# Processing Record 538 of Set 11 | canico
# Processing Record 539 of Set 11 | kysyl-syr
# Processing Record 540 of Set 11 | waingapu
# Processing Record 541 of Set 11 | kedougou
# Processing Record 542 of Set 11 | bacuit
# City not found. Skipping....
# Processing Record 543 of Set 11 | boyolangu
# Processing Record 544 of Set 11 | turukhansk
# Processing Record 545 of Set 11 | biaora
# Processing Record 546 of Set 11 | komsomolets
# Processing Record 547 of Set 11 | boa vista
# Processing Record 548 of Set 11 | katherine
# Processing Record 549 of Set 11 | byron bay
# Processing Record 550 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 551 of Set 11 | katsiveli
# City not found. Skipping....
# Processing Record 552 of Set 11 | shimoda
# Processing Record 553 of Set 11 | wattegama
# Processing Record 554 of Set 11 | zhoucheng
# Processing Record 555 of Set 11 | jacmel
# Processing Record 556 of Set 11 | yomitan
# City not found. Skipping....
# Processing Record 557 of Set 11 | teruel
# Processing Record 558 of Set 11 | sept-iles
# Processing Record 559 of Set 11 | itaituba
# Processing Record 560 of Set 11 | tarko-sale
# Processing Record 562 of Set 12 | ust-nera
# Processing Record 563 of Set 12 | ituni
# City not found. Skipping....
# Processing Record 564 of Set 12 | marshfield
# Processing Record 565 of Set 12 | atbasar
# Processing Record 566 of Set 12 | nishihara
# Processing Record 567 of Set 12 | ust-ishim
# Processing Record 568 of Set 12 | kibondo
# Processing Record 569 of Set 12 | chatsu
# City not found. Skipping....
# Processing Record 570 of Set 12 | santa maria
# Processing Record 571 of Set 12 | barra dos coqueiros
# Processing Record 572 of Set 12 | manokwari
# Processing Record 573 of Set 12 | milingimbi
# City not found. Skipping....
# Processing Record 574 of Set 12 | ji-parana
# City not found. Skipping....
# Processing Record 575 of Set 12 | tupiza
# Processing Record 576 of Set 12 | orcopampa
# Processing Record 577 of Set 12 | hanko
# Processing Record 578 of Set 12 | karratha
# Processing Record 579 of Set 12 | sibu
# Processing Record 580 of Set 12 | vostok
# Processing Record 581 of Set 12 | awbari
# Processing Record 582 of Set 12 | rincon
# Processing Record 583 of Set 12 | fortuna
# Processing Record 584 of Set 12 | te anau
# Processing Record 585 of Set 12 | maldonado
# Processing Record 586 of Set 12 | dalvik
# Processing Record 587 of Set 12 | sola
# Processing Record 588 of Set 12 | maceio
# Processing Record 589 of Set 12 | gravdal
# Processing Record 590 of Set 12 | amarante do maranhao
# Processing Record 591 of Set 12 | sao miguel do araguaia
# Processing Record 592 of Set 12 | harper
# Processing Record 593 of Set 12 | goundam
# Processing Record 594 of Set 12 | tigre
# Processing Record 595 of Set 12 | north myrtle beach
# Processing Record 596 of Set 12 | juneau
# Processing Record 597 of Set 12 | palmas
# Processing Record 598 of Set 12 | skelleftea
# Processing Record 599 of Set 12 | stratford-upon-avon
# Processing Record 600 of Set 12 | carballo
# Processing Record 601 of Set 12 | nome
# Processing Record 602 of Set 12 | san matias
# Processing Record 603 of Set 12 | college
# Processing Record 604 of Set 12 | zaoyang
# Processing Record 605 of Set 12 | opuwo
# Processing Record 606 of Set 12 | mesyagutovo
# Processing Record 607 of Set 12 | sakakah
# Processing Record 608 of Set 12 | ewo
# Processing Record 609 of Set 12 | brooks
# Processing Record 610 of Set 12 | luderitz
# Processing Record 611 of Set 12 | awka
# Processing Record 613 of Set 13 | khasan
# Processing Record 614 of Set 13 | dataganj
# Processing Record 615 of Set 13 | panaba
# Processing Record 616 of Set 13 | luorong
# Processing Record 617 of Set 13 | goderich
# Processing Record 618 of Set 13 | burns lake
# Processing Record 619 of Set 13 | malwan
# City not found. Skipping....
# Processing Record 620 of Set 13 | bac lieu
# Processing Record 621 of Set 13 | guadalajara
# Processing Record 622 of Set 13 | mitu
# Processing Record 623 of Set 13 | salisbury
# Processing Record 624 of Set 13 | tocopilla
# Processing Record 625 of Set 13 | kalevala
# Processing Record 626 of Set 13 | gimbi
# Processing Record 627 of Set 13 | celestun
# Processing Record 628 of Set 13 | masuguru
# Processing Record 629 of Set 13 | saryg-sep
# Processing Record 630 of Set 13 | sacramento
# Processing Record 631 of Set 13 | khromtau
# Processing Record 632 of Set 13 | scalea
# Processing Record 633 of Set 13 | slavsk
# Processing Record 634 of Set 13 | holetown
# Processing Record 635 of Set 13 | saint-augustin
# Processing Record 636 of Set 13 | fianarantsoa
# Processing Record 637 of Set 13 | moindou
# Processing Record 638 of Set 13 | bandarban
# Processing Record 639 of Set 13 | nanakuli
# Processing Record 640 of Set 13 | salamiyah
# Processing Record 641 of Set 13 | casablanca
# Processing Record 642 of Set 13 | bongor
# Processing Record 643 of Set 13 | olafsvik
# Processing Record 644 of Set 13 | ishigaki
# Processing Record 645 of Set 13 | rawson
# Processing Record 646 of Set 13 | floro
# Processing Record 647 of Set 13 | west bay
# Processing Record 648 of Set 13 | iwo
# Processing Record 649 of Set 13 | bougouni
# Processing Record 650 of Set 13 | velez-malaga
# Processing Record 651 of Set 13 | puerto colombia
# Processing Record 652 of Set 13 | arona
# Processing Record 653 of Set 13 | chitipa
# Processing Record 654 of Set 13 | palasa
# Processing Record 655 of Set 13 | nkhata bay
# Processing Record 656 of Set 13 | santa rosa
# Processing Record 657 of Set 13 | cumaribo
# City not found. Skipping....
# Processing Record 658 of Set 13 | winnemucca
# Processing Record 659 of Set 13 | urengoy
# Processing Record 660 of Set 13 | valdivia
# Processing Record 661 of Set 13 | tukrah
# Processing Record 662 of Set 13 | barawe
# City not found. Skipping....
# Processing Record 664 of Set 14 | borogontsy
# Processing Record 665 of Set 14 | lockhart
# Processing Record 666 of Set 14 | honiara
# Processing Record 667 of Set 14 | kirakira
# Processing Record 668 of Set 14 | bonanza
# Processing Record 669 of Set 14 | hualmay
# Processing Record 670 of Set 14 | zemio
# Processing Record 671 of Set 14 | jinchang
# Processing Record 672 of Set 14 | patti
# Processing Record 673 of Set 14 | maragogi
# Processing Record 674 of Set 14 | pochutla
# Processing Record 675 of Set 14 | ghanzi
# Processing Record 676 of Set 14 | lincoln
# Processing Record 677 of Set 14 | faridpur
# Processing Record 678 of Set 14 | vikhorevka
# Processing Record 679 of Set 14 | dawson creek
# Processing Record 680 of Set 14 | washington
# Processing Record 681 of Set 14 | doctor pedro p. pena
# City not found. Skipping....
# Processing Record 682 of Set 14 | yining
# Processing Record 683 of Set 14 | tongsa
# City not found. Skipping....
# Processing Record 684 of Set 14 | nioro
# Processing Record 685 of Set 14 | nyurba
# Processing Record 686 of Set 14 | elk plain
# Processing Record 687 of Set 14 | dulce grande
# Processing Record 688 of Set 14 | praia
# Processing Record 689 of Set 14 | bellview
# Processing Record 690 of Set 14 | joshimath
# Processing Record 691 of Set 14 | huarmey
# Processing Record 692 of Set 14 | punta cardon
# Processing Record 693 of Set 14 | saint-honore
# Processing Record 694 of Set 14 | nelspruit
# Processing Record 695 of Set 14 | monteagudo
# Processing Record 696 of Set 14 | nchelenge
# Processing Record 697 of Set 14 | oildale
# Processing Record 698 of Set 14 | alotau
# City not found. Skipping....
# Processing Record 699 of Set 14 | kerman
# Processing Record 700 of Set 14 | puerto lopez
# Processing Record 701 of Set 14 | anupgarh
# Processing Record 702 of Set 14 | tazovskiy
# Processing Record 703 of Set 14 | howard springs
# Processing Record 704 of Set 14 | hede
# Processing Record 705 of Set 14 | karpogory
# Processing Record 706 of Set 14 | myanaung
# Processing Record 707 of Set 14 | kjollefjord
# Processing Record 708 of Set 14 | karauzyak
# City not found. Skipping....
# Processing Record 709 of Set 14 | vila
# Processing Record 710 of Set 14 | lapithos
# Processing Record 711 of Set 14 | alice springs
# Processing Record 712 of Set 14 | mindelo
# Processing Record 713 of Set 14 | bayji
# Processing Record 715 of Set 15 | urucara
# Processing Record 716 of Set 15 | flinders
# Processing Record 717 of Set 15 | pangoa
# Processing Record 718 of Set 15 | jumla
# Processing Record 719 of Set 15 | kahului
# Processing Record 720 of Set 15 | natal
# Processing Record 721 of Set 15 | vanimo
# Processing Record 722 of Set 15 | freeport
# Processing Record 723 of Set 15 | bonavista
# Processing Record 724 of Set 15 | cockburn town
# Processing Record 725 of Set 15 | dwarka
# Processing Record 726 of Set 15 | stokmarknes
# Processing Record 727 of Set 15 | umm kaddadah
# Processing Record 728 of Set 15 | chara
# Processing Record 729 of Set 15 | mazarron
# Processing Record 730 of Set 15 | rapu-rapu
# Processing Record 731 of Set 15 | sagua la grande
# Processing Record 732 of Set 15 | pemba
# Processing Record 733 of Set 15 | gorno-chuyskiy
# City not found. Skipping....
# Processing Record 734 of Set 15 | ler
# Processing Record 735 of Set 15 | hunza
# City not found. Skipping....
# Processing Record 736 of Set 15 | doume
# Processing Record 737 of Set 15 | cangzhou
# Processing Record 738 of Set 15 | pierre
# Processing Record 739 of Set 15 | mayo
# Processing Record 740 of Set 15 | richards bay
# Processing Record 741 of Set 15 | shache
# Processing Record 742 of Set 15 | bay roberts
# Processing Record 743 of Set 15 | evensk
# Processing Record 744 of Set 15 | mollendo
# Processing Record 745 of Set 15 | sendhwa
# Processing Record 746 of Set 15 | antalaha
# Processing Record 747 of Set 15 | lianzhou
# Processing Record 748 of Set 15 | manggar
# Processing Record 749 of Set 15 | vila velha
# Processing Record 750 of Set 15 | beringovskiy
# Processing Record 751 of Set 15 | santiago de cao
# Processing Record 752 of Set 15 | arkhangelsk
# Processing Record 753 of Set 15 | sorong
# Processing Record 754 of Set 15 | plettenberg bay
# Processing Record 755 of Set 15 | coahuayana
# Processing Record 756 of Set 15 | rtishchevo
# Processing Record 757 of Set 15 | taltal
# Processing Record 758 of Set 15 | amuntai
# Processing Record 759 of Set 15 | linhares
# Processing Record 760 of Set 15 | kurumkan
# Processing Record 761 of Set 15 | marysville
# Processing Record 762 of Set 15 | bida
# Processing Record 763 of Set 15 | bristol
# Processing Record 764 of Set 15 | nakhon sawan
# --------------------------
# Data Retrieval Complete
# --------------------------

# %%
len(city_data)
# Out:
# 691

# %%
city_data_df = pd.DataFrame(city_data)
city_data_df.head(20)
# Out:
#               City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0         Bilibino  68.0546  166.4372     46.45        69         100
# 1   Port Macquarie -31.4333  152.9167     62.56        51           0
# 2      Ferme-Neuve  46.7001  -75.4493     64.18        68           0
# 3         Hermanus -34.4187   19.2345     53.91        77           0
# 4          Ushuaia -54.8000  -68.3000     35.26        75           0
# 5            Paita  -5.0892  -81.1144     64.49        88           9
# 6     Punta Arenas -53.1500  -70.9167     42.91        93          90
# 7        Mahebourg -20.4081   57.7000     70.09        73          75
# 8      Yellowknife  62.4560 -114.3525     59.52        94          75
# 9       Tombouctou  20.0000   -3.0000     96.76        11           8
# 10          Albany  42.6001  -73.9662     72.25        54          14
# 11         Okhotsk  59.3833  143.3000     65.37        77          55
# 12     Ulaanbaatar  47.9077  106.8832     59.13        77           0
# 13           Hanna  51.6334 -111.9018     98.24        15          57
# 14          Namibe -15.1961   12.1522     64.90        90          28
# 15         Suslovo  56.2167   88.1167     55.17        78         100
# 16        Khatanga  71.9667  102.5000     58.46        52          53
# 17           Bluff -46.6000  168.3333     54.81        73          94
# 18    Constitucion -35.3333  -72.4167     47.28        88          99
# 19           Kapaa  22.0752 -159.3190     87.78        67           1
#
#     Wind Speed Country                 Date Current Description
# 0         9.04      RU  2021-08-15 00:34:45     overcast clouds
# 1         4.70      AU  2021-08-15 00:31:25           clear sky
# 2         4.16      CA  2021-08-15 00:34:45           clear sky
# 3        11.34      ZA  2021-08-15 00:34:46           clear sky
# 4         3.44      AR  2021-08-15 00:34:46           clear sky
# 5        15.30      PE  2021-08-15 00:34:46           clear sky
# 6         6.91      CL  2021-08-15 00:34:47          light rain
# 7        11.50      MU  2021-08-15 00:34:47          light rain
# 8        16.11      CA  2021-08-15 00:30:22          light rain
# 9         6.24      ML  2021-08-15 00:34:47           clear sky
# 10        1.99      US  2021-08-15 00:32:35          few clouds
# 11        3.47      RU  2021-08-15 00:34:48       broken clouds
# 12        2.24      MN  2021-08-15 00:32:17           clear sky
# 13        5.99      CA  2021-08-15 00:34:48       broken clouds
# 14        2.86      AO  2021-08-15 00:34:49    scattered clouds
# 15        2.04      RU  2021-08-15 00:34:49     overcast clouds
# 16        6.17      RU  2021-08-15 00:34:50       broken clouds
# 17       19.86      NZ  2021-08-15 00:34:50     overcast clouds
# 18        1.74      CL  2021-08-15 00:34:51     overcast clouds
# 19        5.01      US  2021-08-15 00:34:51           clear sky

# %%
column_order = ["City","Country", "Date", "Lat", "Lng", "Max Temp", "Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[column_order]

# %%
city_data_df.head(20)
# Out:
#               City Country                 Date      Lat       Lng  Max Temp  \
# 0         Bilibino      RU  2021-08-15 00:34:45  68.0546  166.4372     46.45
# 1   Port Macquarie      AU  2021-08-15 00:31:25 -31.4333  152.9167     62.56
# 2      Ferme-Neuve      CA  2021-08-15 00:34:45  46.7001  -75.4493     64.18
# 3         Hermanus      ZA  2021-08-15 00:34:46 -34.4187   19.2345     53.91
# 4          Ushuaia      AR  2021-08-15 00:34:46 -54.8000  -68.3000     35.26
# 5            Paita      PE  2021-08-15 00:34:46  -5.0892  -81.1144     64.49
# 6     Punta Arenas      CL  2021-08-15 00:34:47 -53.1500  -70.9167     42.91
# 7        Mahebourg      MU  2021-08-15 00:34:47 -20.4081   57.7000     70.09
# 8      Yellowknife      CA  2021-08-15 00:30:22  62.4560 -114.3525     59.52
# 9       Tombouctou      ML  2021-08-15 00:34:47  20.0000   -3.0000     96.76
# 10          Albany      US  2021-08-15 00:32:35  42.6001  -73.9662     72.25
# 11         Okhotsk      RU  2021-08-15 00:34:48  59.3833  143.3000     65.37
# 12     Ulaanbaatar      MN  2021-08-15 00:32:17  47.9077  106.8832     59.13
# 13           Hanna      CA  2021-08-15 00:34:48  51.6334 -111.9018     98.24
# 14          Namibe      AO  2021-08-15 00:34:49 -15.1961   12.1522     64.90
# 15         Suslovo      RU  2021-08-15 00:34:49  56.2167   88.1167     55.17
# 16        Khatanga      RU  2021-08-15 00:34:50  71.9667  102.5000     58.46
# 17           Bluff      NZ  2021-08-15 00:34:50 -46.6000  168.3333     54.81
# 18    Constitucion      CL  2021-08-15 00:34:51 -35.3333  -72.4167     47.28
# 19           Kapaa      US  2021-08-15 00:34:51  22.0752 -159.3190     87.78
#
#     Humidity  Cloudiness  Wind Speed Current Description
# 0         69         100        9.04     overcast clouds
# 1         51           0        4.70           clear sky
# 2         68           0        4.16           clear sky
# 3         77           0       11.34           clear sky
# 4         75           0        3.44           clear sky
# 5         88           9       15.30           clear sky
# 6         93          90        6.91          light rain
# 7         73          75       11.50          light rain
# 8         94          75       16.11          light rain
# 9         11           8        6.24           clear sky
# 10        54          14        1.99          few clouds
# 11        77          55        3.47       broken clouds
# 12        77           0        2.24           clear sky
# 13        15          57        5.99       broken clouds
# 14        90          28        2.86    scattered clouds
# 15        78         100        2.04     overcast clouds
# 16        52          53        6.17       broken clouds
# 17        73          94       19.86     overcast clouds
# 18        88          99        1.74     overcast clouds
# 19        67           1        5.01           clear sky

# %%
complete_df = "../Weather_Database/WeatherPy_Database.csv"

city_data_df.to_csv(complete_df, index_label= "City_ID")
